# %%
from pinpoint import TagDictionary

# %%
tag_dict = TagDictionary(tag_shape=(4,4), distance=4, random_seed=50)

# %%
tag_dict.generate_dict(verbose=True)
# Out:
# Generating tags. This may take awhile...
# Iteration: 10000/99999
# Tags found:  158
# Iteration: 20000/99999
# Tags found:  171
# Iteration: 30000/99999
# Tags found:  174
# Iteration: 40000/99999
# Tags found:  178
# Iteration: 50000/99999
# Tags found:  180
# Iteration: 60000/99999
# Tags found:  182
# Iteration: 70000/99999
# Tags found:  183
# Iteration: 80000/99999
# Tags found:  184
# Iteration: 90000/99999
# Tags found:  184
# Iteration: 99999/99999
# Tags found:  184
# Done!
# <pinpoint.TagDictionary.TagDictionary instance at 0x7f14be9eb3f8>

# %%
tag_dict.print_tags('test.pdf')
# Out:
# True

# %%
tag_dict.save_dict('test.pkl')
# Out:
# True
